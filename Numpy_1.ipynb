# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay-Chaudhari/My-Work-on-Git/blob/main/Numpy_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import misc
from PIL import Image

# %%
img=misc.face()
plt.imshow(img)
# Out:
# <ipython-input-2-c42b6e277ea2>:1: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   img=misc.face()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (768, 1024, 3)

# %%
img.ndim
# Out:
# 3

# %%
sRGB_array = img / 255

# %%
grey_vals = np.array([0.2126, 0.7152, 0.0722])

# %%
img_gray = sRGB_array @ grey_vals
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray)

# %%
plt.imshow(np.flip(img_gray), cmap='gray')
